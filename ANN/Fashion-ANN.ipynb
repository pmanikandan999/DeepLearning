# %%
# import basic LIB
import pandas as pd
import numpy as np
# Visualization LIB
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation LIB

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# DeepLearning LIB
import tensorflow as ts
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
#fashion_train

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
#Reshaping the dataset
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)

#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
#Creating base neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])

#Compiling the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

#Fitting the model
history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# 600/600 [==============================] - 9s 10ms/step - loss: 1.0610 - accuracy: 0.6296 - val_loss: 0.5558 - val_accuracy: 0.7785
# Epoch 2/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.7200 - accuracy: 0.7534 - val_loss: 0.4785 - val_accuracy: 0.8341
# Epoch 3/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6618 - accuracy: 0.7768 - val_loss: 0.4708 - val_accuracy: 0.8401
# Epoch 4/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6209 - accuracy: 0.7947 - val_loss: 0.4407 - val_accuracy: 0.8495
# Epoch 5/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6007 - accuracy: 0.8007 - val_loss: 0.4533 - val_accuracy: 0.8527
# Epoch 6/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5861 - accuracy: 0.8024 - val_loss: 0.4757 - val_accuracy: 0.8484
# Epoch 7/30
# 600/600 [==============================] - 6s 11ms/step - loss: 0.5708 - accuracy: 0.8098 - val_loss: 0.4997 - val_accuracy: 0.8621
# Epoch 8/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5708 - accuracy: 0.8073 - val_loss: 0.4164 - val_accuracy: 0.8607
# Epoch 9/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5624 - accuracy: 0.8115 - val_loss: 0.4434 - val_accuracy: 0.8641
# Epoch 10/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5476 - accuracy: 0.8156 - val_loss: 0.4652 - val_accuracy: 0.8620
# Epoch 11/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5446 - accuracy: 0.8178 - val_loss: 0.4125 - val_accuracy: 0.8703
# Epoch 12/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5442 - accuracy: 0.8207 - val_loss: 0.4311 - val_accuracy: 0.8665
# Epoch 13/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5339 - accuracy: 0.8237 - val_loss: 0.4283 - val_accuracy: 0.8638
# Epoch 14/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5357 - accuracy: 0.8209 - val_loss: 0.4053 - val_accuracy: 0.8647
# Epoch 15/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5266 - accuracy: 0.8233 - val_loss: 0.4568 - val_accuracy: 0.8656
# Epoch 16/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5401 - accuracy: 0.8176 - val_loss: 0.4654 - val_accuracy: 0.8706
# Epoch 17/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5341 - accuracy: 0.8210 - val_loss: 0.5167 - val_accuracy: 0.8600
# Epoch 18/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5304 - accuracy: 0.8237 - val_loss: 0.3953 - val_accuracy: 0.8687
# Epoch 19/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5280 - accuracy: 0.8232 - val_loss: 0.4583 - val_accuracy: 0.8685
# Epoch 20/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5244 - accuracy: 0.8242 - val_loss: 0.4545 - val_accuracy: 0.8689
# Epoch 21/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5265 - accuracy: 0.8244 - val_loss: 0.4610 - val_accuracy: 0.8752
# Epoch 22/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5220 - accuracy: 0.8267 - val_loss: 0.4697 - val_accuracy: 0.8706
# Epoch 23/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5157 - accuracy: 0.8287 - val_loss: 0.6126 - val_accuracy: 0.8701
# Epoch 24/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5184 - accuracy: 0.8264 - val_loss: 0.5280 - val_accuracy: 0.8690
# Epoch 25/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5143 - accuracy: 0.8304 - val_loss: 0.5996 - val_accuracy: 0.8701
# Epoch 26/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5073 - accuracy: 0.8305 - val_loss: 0.4691 - val_accuracy: 0.8699
# Epoch 27/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5086 - accuracy: 0.8322 - val_loss: 0.5656 - val_accuracy: 0.8692
# Epoch 28/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5040 - accuracy: 0.8308 - val_loss: 0.3937 - val_accuracy: 0.8669
# Epoch 29/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5134 - accuracy: 0.8271 - val_loss: 0.4975 - val_accuracy: 0.8713
# Epoch 30/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5121 - accuracy: 0.8284 - val_loss: 0.3995 - val_accuracy: 0.8704

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3995 - accuracy: 0.8704

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8704

# %%
#Predicting the labels-Fashion
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-v0_8-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82      1000
#            1       0.99      0.98      0.98      1000
#            2       0.85      0.73      0.79      1000
#            3       0.88      0.90      0.89      1000
#            4       0.74      0.89      0.81      1000
#            5       0.99      0.88      0.93      1000
#            6       0.74      0.58      0.65      1000
#            7       0.86      0.97      0.91      1000
#            8       0.98      0.96      0.97      1000
#            9       0.94      0.93      0.93      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
#tf.expand_dims(X_test_digit[0])
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) # Here we get the index of maximum value in the encoded vector
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# 1/1 [==============================] - 0s 56ms/step

# %%
#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))

plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
